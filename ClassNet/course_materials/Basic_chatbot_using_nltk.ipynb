# %% [markdown]
# ## Simple chatbots using nltk
# keyword matching with pairs of responses

# %%
import nltk

# %%
# %config Completer.use_jedi = False

# %%
# the reflections dictionary maps first-person phrases to second-person
from nltk.chat.util import Chat, reflections

# %%
# each pair has a regex to match user input, and a set of possible responses (chosen at random)
# note we can refer to captured groups (strings) in the output
# the final pattern is a catchall
pairs = [
    [
        r".*hi|hello|hey|what's up.*", 
        ["Hello, I am a simple chatbot. How are you?"]
    ],
    [
        r'.*(how are you|and you).*', 
        ["Doing well, thank you.", "I'm ok, what's new?"]
    ],
    [
        r"quit", 
        ["Bye, nice talking to you!", "Talk to you later!"]
    ],
    [
        r".*weather|rain|snow|sun.*", 
        ["Isn't it nice out today?", "Hopefully, tomorrow the weather will get better.", "I don't know about you, but I am glad I am inside today."]
    ],
    [
        r"I like (.*)", 
        ["Why do you like %1?", "What about %1 do you like?"]
    ],
    [
        r".*(tasty).*", 
        ["Yeah, I think so too."]
    ],
    [
        r".*", 
        ["I am sorry, I don't understand. I am a very simple chatbot!"]
    ]
]

# %%
chatbot = Chat(pairs, reflections)

# %%
# begin a conversation
chatbot.converse()
# Out:
# >hello
# Hello, I am a simple chatbot. How are you?
# >not bad thanks
# I am sorry, I don't understand. I am a very simple chatbot!
# >ok
# I am sorry, I don't understand. I am a very simple chatbot!
# >errr.
# I am sorry, I don't understand. I am a very simple chatbot!
# >what's the weather like
# I don't know about you, but I am glad I am inside today.
# >i like cheese
# What about cheese do you like?
# >its tasty
# Yeah, I think so too.
# >quit
# Bye, nice talking to you!

# %%
# we could override the default reflections
reflections
# Out:
# {'i am': 'you are',
#  'i was': 'you were',
#  'i': 'you',
#  "i'm": 'you are',
#  "i'd": 'you would',
#  "i've": 'you have',
#  "i'll": 'you will',
#  'my': 'your',
#  'you are': 'I am',
#  'you were': 'I was',
#  "you've": 'I have',
#  "you'll": 'I will',
#  'your': 'my',
#  'yours': 'mine',
#  'you': 'me',
#  'me': 'you'}

# %% [markdown]
# ## Other nltk chatbots

# %%
from nltk.chat import eliza_chat
eliza_chat()
# Out:
# Therapist
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ...
# Hello.  How are you feeling today?
# >terrible
# How does that make you feel?
# >bad
# I see.
# >and me
# Please tell me more.
# >My cat is hngry
# When your cat is hngry, how do you feel?
# >bad
# Let's change focus a bit... Tell me about your family.
# >bye
# Please tell me more.
# >quit
# Good-bye.

# %%
from nltk.chat import iesha_chat
iesha_chat()
# Out:
# Iesha the TeenBoT
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ...
# hi!! i'm iesha! who r u??!
# >mc hammer
# do u like anime?
# >yup
# ur funny! kekeke
# >bye
# do u watch anime? i like sailor moon! ^_^
# >quit
# mom says i have to go eat dinner now :,( bye!!

# %%
from nltk.chat import rude_chat
rude_chat()
# Out:
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ...
# I suppose I should say hello.
# >go on then
# I'm getting bored here. Become more interesting.
# >quit
# I'm getting bored here. Become more interesting.

# %%
from nltk.chat import suntsu_chat
suntsu_chat()
# Out:
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ...
# You seek enlightenment?
# >maybe
# If you know yourself but not the enemy, for every victory gained you will also suffer a defeat.
# >quit
# Plan well

# %%
from nltk.chat import zen_chat
zen_chat()
# Out:
# ***************************************************************************
#                                 Zen Chatbot!
# ***************************************************************************
#          "Look beyond mere words and letters - look into your mind"
# * Talk your way to truth with Zen Chatbot.
# * Type 'quit' when you have had enough.
# ***************************************************************************
# Welcome, my child.
# >ta duck
# The reverse side also has a reverse side.
# >lol
# Random talk is useless.
# >really?
# Do you think really?
# >yes
# Is there certainty in an uncertain world?
# >quit
# I pour out a cup of water. Is the cup empty?
